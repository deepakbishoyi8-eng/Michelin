# %%
We will write notebooks in Python, Scala, SQL, and R

# %% [markdown]
# #### Import DataFrame using .csv

# %%
dfr=spark.read
df=dfr.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
           header=True,
           inferSchema=True)
display(df)

# %% [markdown]
# ### Import DataFrame using delimiter

# %%
dfr=spark.read
df=dfr.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",
           header=True,
           inferSchema=True,
           sep="|")
display(df)

# %% [markdown]
# ### Import DataFrame using .parquet

# %%
dfr=spark.read
df=dfr.parquet("/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users.parquet")
display(df)

# %% [markdown]
# ### Import DataFrame using .json

# %%
dfr=spark.read
df=dfr.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",
           multiLine=True)
display(df)

# %% [markdown]
# ### Import data with schema specified

# %%
from pyspark.sql.types import *

USER_SCHEMA = StructType(
    [
        StructField("id", IntegerType()),
        StructField("age", IntegerType()),
        StructField("gender", IntegerType()),
        StructField("designation", StringType()),
        StructField("salary", IntegerType()),
    ]
)
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    schema=USER_SCHEMA
)
df.display()

# %% [markdown]
# ## Handle exception in DataFrame Creation

# %% [markdown]
# ### PERMISSIVE With column rename

# %%
spark.read.option("columnNameOfCorruptRecord", "bad_record").json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json"
).display()

# %% [markdown]
# ### DROPMALFORMED

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
    mode="DROPMALFORMED"
).display()

# %% [markdown]
# ### FAILFAST

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
    mode="FAILFAST"
).display()

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1",
    format="JSON",
)
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1"
).display()

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1",
    format="JSON",
    mode="overwrite",
)
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1"
).display()

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1",
    format="JSON",
    mode="append",
)
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1"
).display()

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1",
    format="JSON",
    mode="errorifexists"
)
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1"
).display()

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1",
    format="JSON",
    mode="ignore"
)
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output/output_json1"
).display()
